# %% [markdown]
# <a href="https://colab.research.google.com/github/ashoollakhani/ML-Project/blob/main/Handout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Connect Google Colab to Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
path = '/content/drive/MyDrive/ML Project/'
# Out:
# Mounted at /content/drive

# %%
#import the standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#run this command to have seaborn override the plt visual style
sns.set()

# %% [markdown]
# Read the CSV file

# %%
df = pd.read_csv(path + 'Data/world_citizens.csv', sep=";")

#as a good practice, avoid working on the dataset you import and create a copy instead
data = df.copy()

# %%
data.head(1)
# Out:
#   avg_monthly_entertainment_expenses avg_weekly_exercise_hours  citizen_id  \
# 0                              8,873                         0           1
#
#      city country date_of_birth eco_consciousness_score education_level  \
# 0  Palmas  Brazil    15/02/1982                       0          5,5454
#
#   environmental_awareness_rating financial_wellness_index  ...  \
# 0                         0,5576                  264,346  ...
#
#   investment_portfolio_value investments_risk_appetite  \
# 0                     0,1313                    6,7866
#
#   investments_risk_tolerance last_year_charity_donations marital_status  \
# 0                     22,955                           0
#
#       name social_media_influence_score stress_management_score title  \
# 0  Mafalda                       2,6469                  3,0448   Ms.
#
#   well_being_level
# 0           3,9098
#
# [1 rows x 22 columns]

# %%
data.head(5)
# Out:
#   avg_monthly_entertainment_expenses avg_weekly_exercise_hours  citizen_id  \
# 0                              8,873                         0           1
# 1                            10,9348                    0,1298           2
# 2                            29,9206                    0,1129           3
# 3                            36,0014                    0,0419           4
# 4                             6,0075                    1,2697           5
#
#      city      country date_of_birth eco_consciousness_score education_level  \
# 0  Palmas       Brazil    15/02/1982                       0          5,5454
# 1   Taupo  New Zealand    07/11/1989                       0           4,915
# 2   Nauen      Germany    13/03/1972                       0          9,4307
# 3   Kusel      Germany    28/04/1982                  0,0134          8,5129
# 4    Rize       Turkey    05/09/1996                       0          6,0902
#
# ...

# %%
data.head(10)
# Out:
#   avg_monthly_entertainment_expenses avg_weekly_exercise_hours  citizen_id  \
# 0                              8,873                         0           1
# 1                            10,9348                    0,1298           2
# 2                            29,9206                    0,1129           3
# 3                            36,0014                    0,0419           4
# 4                             6,0075                    1,2697           5
# 5                            40,3968                         0           6
# 6                            27,8496                         0           7
# 7                            40,4608                         0           8
# 8                             8,4585                       NaN           9
# 9                             5,3042                         0          10
#
#                city         country date_of_birth eco_consciousness_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8327 entries, 0 to 8326
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   avg_monthly_entertainment_expenses  8077 non-null   object
#  1   avg_weekly_exercise_hours           8119 non-null   object
#  2   citizen_id                          8327 non-null   int64
#  3   city                                8327 non-null   object
#  4   country                             8327 non-null   object
#  5   date_of_birth                       8327 non-null   object
#  6   eco_consciousness_score             8119 non-null   object
#  7   education_level                     8036 non-null   object
#  8   environmental_awareness_rating      8294 non-null   object
#  9   financial_wellness_index            8078 non-null   object
#  10  hapiness_level                      8327 non-null   object
# ...

# %% [markdown]
# #

# %%
# print the first 10 rows of avg_weekly_exercise_hours

df['avg_weekly_exercise_hours'].head(10)
# Out:
# 0         0
# 1    0,1298
# 2    0,1129
# 3    0,0419
# 4    1,2697
# 5         0
# 6         0
# 7         0
# 8       NaN
# 9         0
# Name: avg_weekly_exercise_hours, dtype: object

# %% [markdown]
# Check if in the avg_weekly_exercise_hours coulumn if there is any text wirtten

# %%
# check if in the avg_weekly_exercise_hours if there is any row with text and print the row number but only check the ones with letters have in mind the null values aswell

df.loc[df['avg_weekly_exercise_hours'].str.contains('[a-zA-Z]', na=False)]
# Out:
# Empty DataFrame
# Columns: [avg_monthly_entertainment_expenses, avg_weekly_exercise_hours, citizen_id, city, country, date_of_birth, eco_consciousness_score, education_level, environmental_awareness_rating, financial_wellness_index, hapiness_level, health_consciousness_rating, investment_portfolio_value, investments_risk_appetite, investments_risk_tolerance, last_year_charity_donations, marital_status, name, social_media_influence_score, stress_management_score, title, well_being_level]
# Index: []
#
# [0 rows x 22 columns]

# %%
df['avg_weekly_exercise_hours'].describe()
# Out:
# count     8119
# unique    4809
# top          0
# freq      1281
# Name: avg_weekly_exercise_hours, dtype: object

# %%
#plot a graph on avg_weekly_exercise_hours have in mind that the number goes from 0 to 10 with decimals numbers make the plot very precise and that i see the diference

plt.figure(figsize=(10, 6))
sns.histplot(df['avg_weekly_exercise_hours'], bins=100, kde=True)
plt.title('Distribution of Average Weekly Exercise Hours')
plt.xlabel('Average Weekly Exercise Hours')
plt.ylabel('Frequency')
plt.show()
